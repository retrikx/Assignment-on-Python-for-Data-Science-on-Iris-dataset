# %% [markdown]
# # 1. Read the dataset to python environment.

# %%
import pandas as pd
import numpy as np
filename='Downloads/iris.xls'
df=pd.read_excel(filename)
#datafile->df

# %%
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # To display whole data

# %%
import pandas as pd
filename='Downloads/iris.xls'
df=pd.read_excel(filename)
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
df
# Out:
#       SL   SW   PL   PW   Classification
# 0    5.1  3.5  1.4  0.2      Iris-setosa
# 1    4.9  3.0  1.4  0.2      Iris-setosa
# 2    4.7  3.2  1.3  0.2      Iris-setosa
# 3    4.6  3.1  1.5  0.2      Iris-setosa
# 4    5.0  3.6  1.4  0.2      Iris-setosa
# 5    5.4  3.9  1.7  0.4      Iris-setosa
# 6    4.6  3.4  1.4  0.3      Iris-setosa
# 7    5.0  3.4  1.5  0.2      Iris-setosa
# 8    4.4  2.9  1.4  0.2      Iris-setosa
# 9    4.9  3.1  1.5  0.1      Iris-setosa
# 10   5.4  3.7  1.5  0.2      Iris-setosa
# 11   4.8  3.4  1.6  0.2      Iris-setosa
# 12   4.8  3.0  1.4  0.1      Iris-setosa
# 13   4.3  3.0  1.1  0.1      Iris-setosa
# 14   5.8  4.0  1.2  0.2      Iris-setosa
# 15   5.7  4.4  1.5  0.4      Iris-setosa
# 16   5.4  3.9  1.3  0.4      Iris-setosa
# 17   5.1  3.5  1.4  0.3      Iris-setosa
# 18   5.7  3.8  1.7  0.3      Iris-setosa
# 19   5.1  3.8  1.5  0.3      Iris-setosa
# 20   5.4  3.4  1.7  0.2      Iris-setosa
# 21   5.1  3.7  1.5  0.4      Iris-setosa
# ...

# %% [markdown]
# # 2 Display the columns in the dataset

# %%
print(df. columns)
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %%
#pd.set_option('display.max_columns', None)
#print(df)

# %% [markdown]
# # 3 Calculate the mean of each column of the dataset.

# %%
df.mean(axis=0)
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # 4 Check for the null values present in the dataset.

# %%
df.isna().sum()

#for here there is no null value
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # 5 Perform meaningful visualizations using the dataset.

# %%
df.dtypes
# Out:
# SL                float64
# SW                float64
# PL                float64
# PW                float64
# Classification     object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df.groupby('Classification').size()
# Out:
# Classification
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64

# %%
sns.FacetGrid(df, hue="Classification", palette="husl",size=5) \
   .map(plt.scatter, "SL", "SW") \
   .add_legend()

# %%
sns.stripplot(x='PL',y='SL',hue='Classification',data=df)
sns.set(rc={"figure.figsize":(15,6)})
plt.title('Comparison of SL and PL of each flower', fontsize=20)
plt.show()

# %%
df[['SL','SW','PL','PW']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'SL'}>,
#         <AxesSubplot:title={'center':'SW'}>],
#        [<AxesSubplot:title={'center':'PL'}>,
#         <AxesSubplot:title={'center':'PW'}>]], dtype=object)

# %%
#Comparison of SL and PL of each flower through all the plots available
sns.pairplot(df)
